# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13725, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 13725 (delta 2), reused 6 (delta 2), pack-reused 13715
# Receiving objects: 100% (13725/13725), 13.25 MiB | 16.59 MiB/s, done.
# Resolving deltas: 100% (9453/9453), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q ClothingDetection_data.zip
# Out:
# replace ClothingDetection_data/data.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
ls
# Out:
# ClothingDetection_data/     drive/        yessir.zip
# ClothingDetection_data.zip  sample_data/

# %%
# %cd content/yolov5
# %pip install -qr requirements.txt

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.5/107.7 GB disk)

# %%
# !unzip -q ../../ClothingDetection_data.zip -d ../
# Out:
# unzip:  cannot find or open ../../ClothingDetection_data.zip, ../../ClothingDetection_data.zip.zip or ../../ClothingDetection_data.zip.ZIP.

# %% [markdown]
# Begin training

# %%
# !python train.py --img 640 --batch 2 --epochs 150 --data clothingdata.yaml --weights yolov5s.pt --nosave --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=clothingdata.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=2, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CPU
#
# ...

# %%
# !zip -r /content/yolov5_32.zip /content/yolov5/
# Out:
# 	zip warning: missing end signature--probably not a zip file (did you
# 	zip warning: remember to use binary mode when you transferred it?)
# 	zip warning: (if you are trying to read a damaged archive try -F)
#
# zip error: Zip file structure invalid (/content/yolov5_32.zip)

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source ../ClothingDetection_data/test/images
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=../ClothingDetection_data/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# image 1/26 /content/ClothingDetection_data/test/images/------------10_jpg.rf.175c33ec341b809a34ef6722a238b3e1.jpg: 640x640 1 long, 476.2ms
# image 2/26 /content/ClothingDetection_data/test/images/------------15_jpg.rf.9c171a90a07310b79564c4251808a03c.jpg: 640x640 1 long, 413.0ms
# ...

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 20 --epochs 150 --data clothingdata.yaml --weights runs/train/exp/weights/last.pt --cache --exist-ok
# Out:
# train: weights=runs/train/exp/weights/last.pt, cfg=, data=clothingdata.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-189-g2f1eb21 Python-3.7.14 torch-1.12.1+cu113 CPU
#
# ...

# %%
# !python train.py --img 640 --batch 20 --epochs 150 --data clothingdata.yaml --weights runs/train/exp/weights/best.pt --cache --exist-ok
# Out:
# train: weights=runs/train/exp/weights/best.pt, cfg=, data=clothingdata.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 157 (delta 107), reused 141 (delta 98), pack-reused 0
# Receiving objects: 100% (157/157), 43.85 KiB | 14.62 MiB/s, done.
# Resolving deltas: 100% (107/107), completed with 2 local objects.
# ...
